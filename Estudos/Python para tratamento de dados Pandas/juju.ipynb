# %%
import pandas as pd
import numpy as np

df = pd.read_csv('dados_com_faltantes.csv')

df_filled = df.fillna(value=0)  # substitui valores faltantes por zero

print(df_filled.head())
print(df_filled.info())

df_filled.to_csv('dados_tratados.csv', index=False)
# Out:
#    id    nome  idade cidade
# 0   1     Ana   23.0     SP
# 1   2   Bruno    0.0     RJ
# 2   3       0   31.0     BH
# 3   4  Daniel   45.0      0
# 4   5     Eva    0.0    SSA
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      5 non-null      int64
#  1   nome    5 non-null      object
#  2   idade   5 non-null      float64
#  3   cidade  5 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes
# None
